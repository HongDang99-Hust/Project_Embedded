# %% [markdown]
# <a href="https://colab.research.google.com/github/HongDang99-Hust/Project_Embedded/blob/main/Yolo12oc_to.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.5 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="10fsKrINDogbMvwUg6ZM")
project = rf.workspace("ngs-workspace-zni4i").project("my-first-project-imuzh")
version = project.version(2)
dataset = version.download("yolov12")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.9/175.9 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 96.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 140.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-2 in yolov12:: 100%|██████████| 6765/6765 [00:00<00:00, 8174.59it/s]

# %%
from ultralytics import YOLO

# Khởi tạo mô hình (Dùng bản 'n' - Nano hoặc 's' - Small cho băng tải)
model = YOLO('yolo12n.pt')

# Bắt đầu Train:
# epochs=50 (Học 50 vòng)
# imgsz=640 (Độ phân giải ảnh)
results = model.train(data=f"{dataset.location}/data.yaml", epochs=100, imgsz=640, batch=16)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# 1. Kết nối Drive (nếu trước đó bạn chưa kết nối)
from google.colab import drive
import os
drive.mount('/content/drive')

# 2. Tạo thư mục riêng trên Drive để lưu trữ Model cho đồ án
folder_path = '/content/drive/MyDrive/YOLO_Weights_DoAn'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"--- Đã tạo thư mục: {folder_path} ---")

# 3. Copy chính xác 2 file best.pt và last.pt
print("Đang sao lưu các file trọng số...")
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/YOLO_Weights_DoAn/best_nut_bolt.pt
# !cp /content/runs/detect/train/weights/last.pt /content/drive/MyDrive/YOLO_Weights_DoAn/last_nut_bolt.pt

print("✅ Hoàn tất! Bạn có thể vào Drive tìm thư mục 'YOLO_Weights_DoAn' để thấy file.")
# Out:
# Mounted at /content/drive
# --- Đã tạo thư mục: /content/drive/MyDrive/YOLO_Weights_DoAn ---
# Đang sao lưu các file trọng số...
# ✅ Hoàn tất! Bạn có thể vào Drive tìm thư mục 'YOLO_Weights_DoAn' để thấy file.

# %%
# !cp -r /content/runs/detect/train /content/drive/MyDrive/YOLO_Weights_DoAn
print("✅ Đã lưu toàn bộ kết quả vào Google Drive thành công!")
# Out:
# ✅ Đã lưu toàn bộ kết quả vào Google Drive thành công!
